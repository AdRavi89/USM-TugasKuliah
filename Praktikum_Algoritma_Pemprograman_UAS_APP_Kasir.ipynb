# %% [markdown]
# <a href="https://colab.research.google.com/github/AdRavi89/TugasKuliahUSM/blob/main/Praktikum_Algoritma_Pemprograman_UAS_APP_Kasir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nama : AGUNG DWI SUSILO
#NIM : G.231.22.0038
#TUGAS : UAS PRAKTIKUM ALOGORITMA

print("---------------------------------------------")
print("---------------------------------------------")
nama = "kasir"
kunci = "motorku"
lagi='y'
a=0
while lagi=='y':
    username = str(input("Masukan username : "))
    password = str(input("Masukan password : "))
    if username == nama and password == kunci :
        print ("Password Benar")
        break
    elif username == nama or password == kunci:
        print ("User or Password Error")
    else :
        print ("Password Salah")
    a=a+1
    if a==2:
      print ("End Program, 2x Salah Input")
      break
    print()

print("---------------------------------------------")
print("********************************************")
print("-----Aplikasi Sewa Motorku")
print("-----Motor yang bisa dipilih :")
print("-----Beat, Vario, PCX")
print("********************************************")
beat=50000
vario=65000
pcx=80000
print("---------------------------------------------")
nomerTransaksi=int(input("Nomer Transaksi       = "))
namaPenyewa=input("Nama Penyewa          = ")
alamat=input("Alamat                = ")
print("---------------------------------------------")
lamaSewa=int(input("Lama Sewa Berapa Hari = "))
motor=input("Motor                 = ")
print("---------------------------------------------")
if motor == "beat":
  harga=beat*lamaSewa
  if lamaSewa > 2:
      diskon=harga-(harga*0.05)

      print("Harga/Hari            = Rp {:,}".format(int(beat)).replace(',','.'))
      print("Diskon (Sewa > 2 hari)= 5%")
  else :
      diskon = harga
      print("Diskon = anda tidak mendapat diskon")

elif motor == "vario":
  harga=vario*lamaSewa
  if lamaSewa > 2:
      diskon=harga-(harga*0.05)

      print("Harga/Hari            = Rp {:,}".format(int(vario)).replace(',','.'))
      print("Diskon (Sewa > 2 hari)= 5%")
  else :
      diskon = harga
      print("Diskon = anda tidak mendapat diskon")

elif motor == "pcx":
  harga=pcx*lamaSewa
  if lamaSewa > 2:
      diskon=harga-(harga*0.05)
      print("Harga/Hari = ",pcx)

      print("Harga/Hari            = Rp {:,}".format(int(pcx)).replace(',','.'))
      print("Diskon (Sewa > 2 hari)= 5%")
  else :
      diskon = harga
      print("Diskon = anda tidak mendapat diskon")
else:
  print("mohon masukan data yang benar")

print("Total Harga           = Rp {:,}".format(int(diskon)).replace(',','.'))
print("---------------------------------------------")
# Out:
# ---------------------------------------------
# ---------------------------------------------
# Masukan username : Nama Pertama
# Masukan password : Pass Pertama
# Password Salah
#
# Masukan username : Nama Kedua
# Masukan password : Pass Kedua
# Password Salah
# End Program, 2x Salah Input
# ---------------------------------------------
# ********************************************
# -----Aplikasi Sewa Motorku
# -----Motor yang bisa dipilih :
# -----Beat, Vario, PCX
# ********************************************
# ---------------------------------------------
# Nomer Transaksi       = 888789
# Nama Penyewa          = Riyanda
# Alamat                = Semirang
# ---------------------------------------------
# Lama Sewa Berapa Hari = 6
# Motor                 = vario
# ---------------------------------------------
# Harga/Hari            = Rp 65.000
# Diskon (Sewa > 2 hari)= 5%
# Total Harga           = Rp 370.500
# ---------------------------------------------

# %%
#Nama : AGUNG DWI SUSILO
#NIM : G.231.22.0038
#TUGAS : UAS PRAKTIKUM ALOGORITMA

print("---------------------------------------------")
print("---------------------------------------------")
nama = "kasir"
kunci = "motorku"
a=0
while a!=2 :
    username = input ("masukan username : ")
    password = input ("masukan password : ")
    if username == nama and password == kunci :
        print ("password benar")
        break
    elif username == nama or password == kunci:
        print ("user or password error")
    else :
        print ("password salah")
    a=a+1
    if a==2:
      print ("End Program, 2x Salah Input")
      print("---------------------------------------------")
      print("---------------------------------------------")
      break

      print("---------------------------------------------")
      print("********************************************")
      print("-----Aplikasi Sewa Motorku")
      print("-----Motor yang bisa dipilih :")
      print("-----Beat, Vario, PCX")
      print("********************************************")
      beat=50000
      vario=65000
      pcx=80000
      print("---------------------------------------------")
      nomerTransaksi=int(input("Nomer Transaksi       = "))
      namaPenyewa=input("Nama Penyewa          = ")
      alamat=input("Alamat                = ")
      print("---------------------------------------------")
      lamaSewa=int(input("Lama Sewa Berapa Hari = "))
      motor=input("Motor                 = ")
      print("---------------------------------------------")
      if motor == "beat":
        harga=beat*lamaSewa
        if lamaSewa > 2:
            diskon=harga-(harga*0.05)

            print("Harga/Hari            = Rp {:,}".format(int(beat)).replace(',','.'))
            print("Diskon (Sewa > 2 hari)= 5%")
        else :
            diskon = harga
            print("Diskon = anda tidak mendapat diskon")

      elif motor == "vario":
        harga=vario*lamaSewa
        if lamaSewa > 2:
            diskon=harga-(harga*0.05)

            print("Harga/Hari            = Rp {:,}".format(int(vario)).replace(',','.'))
            print("Diskon (Sewa > 2 hari)= 5%")
        else :
            diskon = harga
            print("Diskon = anda tidak mendapat diskon")

      elif motor == "pcx":
        harga=pcx*lamaSewa
        if lamaSewa > 2:
            diskon=harga-(harga*0.05)
            print("Harga/Hari = ",pcx)

            print("Harga/Hari            = Rp {:,}".format(int(pcx)).replace(',','.'))
            print("Diskon (Sewa > 2 hari)= 5%")
        else :
            diskon = harga
            print("Diskon = anda tidak mendapat diskon")
      else:
        print("mohon masukan data yang benar")

      print("Total Harga           = Rp {:,}".format(int(diskon)).replace(',','.'))
      print("---------------------------------------------")
      print("---------------------------------------------")
# Out:
# ---------------------------------------------
# ---------------------------------------------
# masukan username : Masuk Pertama
# masukan password : Pass Pertama
# password salah
# masukan username : Masuk Kedua
# masukan password : Pass Kedua
# password salah
# End Program, 2x Salah Input
# ---------------------------------------------
# ---------------------------------------------

# %%
from IPython.display import clear_output
nama = "admin"
kunci = "admin"
input_ke=0
while input_ke!=2 :
  username = input ("masukan username : ")
  password = input ("masukan password : ")
  if username == nama and password == kunci :
    print ("password benar")
    break
  else :
    print ("password salah")
    input_ke += 1
if input_ke==2:
  clear_output()
  print('Maaf anda 2 kali salah password/username, Gagal Login')
else :
  nomor_transaksi = input('Masukkan Nomor Transaksi : ')
  nama_barang = input('Masukkan Nama Barang : ').lower()
  jumlah_beli = float(input('Masukkan Jumlah Beli : '))
  member = input('Member ? (y/n) : ').lower()
  if(nama_barang == 'buku') :
    harga = 5000
  elif (nama_barang == 'pensil') :
    harga = 2000
  elif (nama_barang == 'pulpen') :
    harga = 4000
  if (member == 'y') :
    diskon = 5
  elif (member == 'n') :
    diskon = 0
  total = harga * jumlah_beli
  diskon_rupiah = total * diskon/100
  total_bayar = total - diskon_rupiah
  # print
  clear_output()
  print('==============================================================')
  print('=================== STRUK PEMBELIAN BARANG ===================')
  print('==============================================================')
  print(f'             Nomor Transaksi = {nomor_transaksi}')
  print(f'             Nama Barang = {nama_barang}')
  print(f'             Harga = Rp.{harga}')
  print(f'             Jumlah Beli = {int(jumlah_beli)} pcs')
  print(f'             Total = Rp.{int(total)}')
  print(f'             Diskon Member = Rp.{int(diskon_rupiah)} ({diskon}%)')
  print(f'             Total Bayar = Rp.{int(total_bayar)}')
  print(f'==============================================================')
  print(f'==============================================================')
